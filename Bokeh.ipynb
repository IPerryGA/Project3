# %%
from bokeh.sampledata.iris import flowers

# %%
from bokeh.plotting import figure

# %%
from bokeh.models import Range1d, PanTool, ResetTool, HoverTool, ColumnDataSource

# %%
import pandas

# %%
from bokeh.io import output_file, show

# %%
#glyphs
colormap={'setosa':'red','versicolor':'green','virginica':'blue'}
flowers['color']=[colormap[x] for x in flowers['species']]

# %%
setosa= ColumnDataSource(flowers[flowers["species"]=="setosa"])
versicolor= ColumnDataSource(flowers[flowers["species"]=="versicolor"])
virginica= ColumnDataSource(flowers[flowers["species"]=="virginica"])

# %%
output_file('iris.html')

# %%
f=figure()

# %%
f.plot_height = 650
f.plot_width = 1100
f.background_fill_color="olive"

# %%
f.title.text='Bokeh Graph - Iris Dataset'
#f.title_text_color='purple'
#f.title_text_font="times"
#f.title_text_font_size=25
f.title.align="center"

# %%
#tools
#f.tools=[PanTool(), ResetTool(),HoverTool()]
f.toolbar.logo=None
f.toolbar_location='right'
hover=HoverTool(tooltips=[('species','@species'),("sepal_width","@sepal_width")])
f.add_tools(hover)

# %%
# Axes
f.axis.minor_tick_line_color="Blue"
f.xaxis.visible=True
f.xaxis.minor_tick_in=-6
f.yaxis.minor_tick_in=-6
f.xaxis.axis_label="Petal Length"
f.yaxis.axis_label="Petal Width"

# %%
# Geometry
f.x_range=Range1d(start=0,end=10)
f.y_range=Range1d(start=0,end=4)

# %%
# Grid
f.xgrid.grid_line_color=None
f.ygrid.grid_line_color=None

# %%
f.circle(x="petal_length", y="petal_width",
         size=[i*4 for i in setosa.data['sepal_width']]*4,
         fill_alpha=0.2,color='color',line_dash=[5,3],legend='Setosa', source=setosa)

f.circle(x="petal_length", y="petal_width",
         size=[i*4 for i in setosa.data['sepal_width']]*4,
         fill_alpha=0.2,color='color',line_dash=[5,3],legend='Versicolor', source=versicolor)

f.circle(x="petal_length", y="petal_width",
         size=[i*4 for i in setosa.data['sepal_width']]*4,
         fill_alpha=0.2,color='color',line_dash=[5,3],legend='Virginica',source=virginica)
# Out:
# /Users/ianperry/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:33: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ianperry/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:33: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ianperry/anaconda/lib/python2.7/site-packages/bokeh/util/deprecation.py:33: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# GlyphRenderer(id='08a08417-409e-43ee-b8ab-8ee11190fa32', ...)

# %%
f.legend.background_fill_alpha=0

# %%
show(f)

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species color
# 0             5.1          3.5           1.4          0.2     setosa   red
# 1             4.9          3.0           1.4          0.2     setosa   red
# 2             4.7          3.2           1.3          0.2     setosa   red
# 3             4.6          3.1           1.5          0.2     setosa   red
# 4             5.0          3.6           1.4          0.2     setosa   red
# 5             5.4          3.9           1.7          0.4     setosa   red
# 6             4.6          3.4           1.4          0.3     setosa   red
# 7             5.0          3.4           1.5          0.2     setosa   red
# 8             4.4          2.9           1.4          0.2     setosa   red
# 9             4.9          3.1           1.5          0.1     setosa   red
# 10            5.4          3.7           1.5          0.2     setosa   red
# ...

# %%
dir(f.grid)
# Out:
# ['__cached_all__overridden_defaults__',
#  '__cached_all__properties__',
#  '__cached_all__properties_with_refs__',
#  '__class__',
#  '__container_props__',
#  '__dataspecs__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__overridden_defaults__',
#  '__properties__',
#  '__properties_with_refs__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__view_model__',
#  '__weakref__',
#  '_attach_document',
#  '_bokeh_repr_pretty_',
#  '_callbacks',
#  '_clone',
#  '_detach_document',
#  '_document',
#  '_id',
#  '_overridden_defaults',
#  '_property_values',
#  '_repr_html_',
#  '_to_json_like',
#  '_visit_immediate_value_references',
#  '_visit_value_and_its_immediate_references',
#  'apply_theme',
#  'band_fill_alpha',
#  'band_fill_color',
#  'bounds',
#  'collect_models',
#  'dataspecs',
# ...
